# %%
# CMT309 - CMT314 2021-2022 Coursework Q1
# Oktay Karakus, PhD
# *******************************************************************
# PLACE YOUR FUNCTIONS HERE AND RUN THIS BIT TO SEE YOUR OUTPUTS FOR ALL THE TEST CASES.
# *******************************************************************
### --- IMPORTANT: DO NOT REMOVE OR CHANGE THE CODE BELOW ---
if __name__ == '__main__':
    testcases = {'do_arithmetic': [(24, -7, 'add'), (6, 6, 'multiply'), (4, 0, '/'), (3, 9, '-')],
                 'do_arithmetic - extra': [(2, 3, '--'), (4, 0, 'MULtiply'), (10, 10)],
                 'sum_of_digits':[("123",), ("we10a20b",), ("united",), ("",)],
                 'sum_of_digits - extra': [("-1000%",), ("*/-987_",), (" ",)]}

    print('\n-- do_arithmetic testcases --')
    for args in testcases['do_arithmetic']:
        print('input:', str(args))
        print('output:', do_arithmetic(*args))
        print('-----------')
    print('\n-- do_arithmetic Extra testcases --')
    for args in testcases['do_arithmetic - extra']:
        print('input:', str(args))
        print('output:', do_arithmetic(*args))
        print('-----------')

    print('\n-- sum_of_digits testcases --')
    for args in testcases['sum_of_digits']:
        print('input:', str(args))
        print('output:', sum_of_digits(*args))
        print('-----------')
    print('\n-- sum_of_digits Extra testcases --')
    for args in testcases['sum_of_digits - extra']:
        print('input:', str(args))
        print('output:', sum_of_digits(*args))
        print('-----------')

#-- do_arithmetic testcases --
#input: (24, -7, 'add')
#output: 17.0
#-----------
#input: (6, 6, 'multiply')
#output: 36.0
#-----------
#input: (4, 0, '/')
#Division by 0!
#output: None
#-----------
#input: (3, 9, '-')
#output: -6.0
#-----------
#
#-- do_arithmetic Extra testcases --
#input: (2, 3, '--')        CHECKING IF YOUR FUNCTION WORKS FOR WRONG SYMBOL ARGUMENTS
#Unknown Operation!
#output: None
#-----------
#input: (4, 0, 'MULtiply')  CHECKING IF YOUR FUNCTION WORKS FOR TEXT OPERATOR ARGUMENTS BUT COMPRISE OF A MIXTURE OF LOWERCASE AND CAPITAL LETTERS
#Unknown Operation!
#output: None
#-----------
#input: (10, 10)            CHECKING IF YOUR FUNCTION DEFINES DEFAULT OPERATOR ARGUMENT
#output: 20.0
#-----------
#
#-- sum_of_digits testcases --
#input: ('123',)
#The sum of digits operation performs 1+2+3
#The extracted non-digits are:  []
#output: 6
#-----------
#input: ('we10a20b',)
#The sum of digits operation performs 1+0+2+0
#The extracted non-digits are:  ['w', 'e', 'a', 'b']
#output: 3
#-----------
#input: ('united',)
#The sum of digits operation could not detect a digit!
#The returned input non-digits are:  ['u', 'n', 'i', 't', 'e', 'd']
#output: 0
#-----------
#input: ('',)
#Empty string entered!
#output: 0
#-----------

#-- sum_of_digits Extra testcases --
#input: ('-1000%',)                                   CHECKING YOUR FUNCTION DISCRIMINATES NEGATIVE NUMBERS
#The sum of digits operation performs 1+0+0+0
#The extracted non-digits are:  ['-', '%']
#output: 1
#-----------
#input: ('*/-987_',)                                  CHECKING YOUR FUNCTION DISCRIMINATES NON-DIGIT & NON-LETTER CHARACTERS
#The sum of digits operation performs 9+8+7
#The extracted non-digits are:  ['*', '/', '-', '_']
#output: 24
#-----------
#input: (' ',)                                        CHECKING YOUR FUNCTION DISCRIMINATES EMPTY STRING AND SPACE CHARACTER
#The sum of digits operation could not detect a digit!
#The returned input non-digits are:  [' ']
#output: 0
#-----------

# %%
# CMT309 - CMT314 2021-2022 Coursework Q2
# Oktay Karakus, PhD
# *******************************************************************
# NO EXTRA TEST CASES USED FOR THIS QUESTION

# %%
# CMT309 - 2021-2022 Coursework Q3
# Oktay Karakus, PhD
# *******************************************************************
# PLACE YOUR FUNCTION HERE AND RUN THIS BIT TO SEE YOUR OUTPUTS FOR ALL THE TEST CASES.
# *******************************************************************
### --- IMPORTANT: DO NOT REMOVE OR CHANGE THE CODE BELOW ---
if __name__ == '__main__':
    # Example 1
    testcases = {
        'example 1':
"""
def add_two_numbers(a, b):
  return a + b

print(add_two_numbers(10, 20))
""",
    'example 2' :
"""
def _major_split(*args):
  return (args[:2], args[2:])

def CheckTruth(t = True):
  print('t is', t)
  return _major_split([t]*10)

x, y = _major_split((10, 20, 30, 40, 50))
CheckTruth(len(x) == 10)
""",
    'Extra case' :
"""
def    __united___great(x):
  for i in x:
    if x>0:
      print("Man United is the greatest of all!")

__united___great(7)
"""
    }
    for key, code in testcases.items():
        print(f'--- {key} ---')
        out = function_renamer(code)
        if not isinstance(out, tuple) or len(out)!=2:
            raise TypeError('function_renamer should return a tuple of length 2')
        d, newcode = out
        if not isinstance(d, dict):
            raise TypeError('return argument d should be a dictionary')
        if not isinstance(newcode, str):
            raise TypeError('return argument code should be a string')
        print('d = ', d)
        print('\ncode:')
        print(newcode)
#
# Extra test case is created to see how flexible is your code when 
#         (1) the number of spaces between the def keyword and function name is not 1, and 
#         (2) the number of underscores (or other characters) is more than 1-2. 
# First expectation is to have a fully working code, returning the output given below. 
# If it does not, that mean your function returns wrong outputs, but not crashes!  
# if your code crashes for the extra test case, you should have received 5 more marks reduction here.
# 
#
#--- example 1 ---
#d =  {'add_two_numbers': {'hash': 8661616449722714930, 'camelcase': 'AddTwoNumbers', 'allcaps': 'ADD_TWO_NUMBERS'}}
#
#code:
#
#def AddTwoNumbers(a, b):
#  return a + b
#
#print(AddTwoNumbers(10, 20))
#
#--- example 2 ---
#d =  {'CheckTruth': {'hash': -7824109733850407647, 'camelcase': 'CheckTruth', 'allcaps': 'CHECKTRUTH'}, '_major_split': {'hash': -6215575408148208886, 'camelcase': '_MajorSplit', 'allcaps': '_MAJOR_SPLIT'}}
#
#code:
#
#def _MajorSplit(*args):
#  return (args[:2], args[2:])
#
#def CheckTruth(t = True):
#  print('t is', t)
#  return _MajorSplit([t]*10)
#
#x, y = _MajorSplit((10, 20, 30, 40, 50))
#CheckTruth(len(x) == 10)
#
#--- Extra case ---
#d =  {'__united___great': {'hash': 5788067316995671501, 'camelcase': '__UnitedGreat', 'allcaps': '__UNITED___GREAT'}}
#
#code:
#
#def    __UnitedGreat(x):
#  for i in x:
#    if x>0:
#      print("Man United is the greatest of all!")
#
#__UnitedGreat(7)
